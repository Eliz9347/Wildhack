# %%
import numpy as np
import pandas as pd

# %%
print("Please insert path to search_history")
# G:\Learning_2021\WildHack\search_history.csv.gz
search_history_path = input()

# %%
df = pd.read_csv(search_history_path)
df
# Out:
#                                  wbuser_id                         UQ    cnt  \
# 0         37bc0ce12ffabce1b1882e66d461ed0e   тапочки женские домашние   1933
# 1         4636a6706e6736d818816d8657565aa2         чехол для бейджика   1513
# 2         708f4040baf99acfc9496563edff1b1a                      GUESS      4
# 3         70311ec9008a31f743c164e6f1198c86           штора для ванной      0
# 4         70311ec9008a31f743c164e6f1198c86                   фототфон  92272
# ...                                    ...                        ...    ...
# 83919234  3a34537ac69a9f7b2664565b106e769e   фиолетовый неон с вилкой      0
# 83919235  c0d75daa762272829028e43a62ff7c75  весы кухонные электронные   1407
# 83919236  70311ec9008a31f743c164e6f1198c86         термобелье мужское   3233
# 83919237  ab988d1855d8b5c260380e942ab8e572                    рубашка  56396
# 83919238  fa123d6ebfc13851cc2ef63cdd55b5ed       набор посудыдля супа      0
#
#          locale  weekday      time
# ...

# %%
file_name = "search.csv"
df.to_csv(file_name, sep='\t', encoding='utf-8')

# %%
df.loc[df['wbuser_id'] == '37bc0ce12ffabce1b1882e66d461ed0e']
# Out:
#                                  wbuser_id                        UQ    cnt  \
# 0         37bc0ce12ffabce1b1882e66d461ed0e  тапочки женские домашние   1933
# 819       37bc0ce12ffabce1b1882e66d461ed0e  тапочки женские домашние   2191
# 202723    37bc0ce12ffabce1b1882e66d461ed0e  тапочки женские домашние   8954
# 216490    37bc0ce12ffabce1b1882e66d461ed0e  тапочки женские домашние   1651
# 226768    37bc0ce12ffabce1b1882e66d461ed0e  тапочки женские домашние     13
# ...                                    ...                       ...    ...
# 83102436  37bc0ce12ffabce1b1882e66d461ed0e    джины на высокой талии  18792
# 83110815  37bc0ce12ffabce1b1882e66d461ed0e    джины на высокой талии  10904
# 83252844  37bc0ce12ffabce1b1882e66d461ed0e    джины на высокой талии  10847
# 83333946  37bc0ce12ffabce1b1882e66d461ed0e    джины на высокой талии  10847
# 83438142  37bc0ce12ffabce1b1882e66d461ed0e    джины на высокой талии  10847
#
#          locale  weekday      time
# ...

# %%
df
# Out:
#                                  wbuser_id                         UQ    cnt  \
# 0         37bc0ce12ffabce1b1882e66d461ed0e   тапочки женские домашние   1933
# 1         4636a6706e6736d818816d8657565aa2         чехол для бейджика   1513
# 2         708f4040baf99acfc9496563edff1b1a                      GUESS      4
# 3         70311ec9008a31f743c164e6f1198c86           штора для ванной      0
# 4         70311ec9008a31f743c164e6f1198c86                   фототфон  92272
# ...                                    ...                        ...    ...
# 83919234  3a34537ac69a9f7b2664565b106e769e   фиолетовый неон с вилкой      0
# 83919235  c0d75daa762272829028e43a62ff7c75  весы кухонные электронные   1407
# 83919236  70311ec9008a31f743c164e6f1198c86         термобелье мужское   3233
# 83919237  ab988d1855d8b5c260380e942ab8e572                    рубашка  56396
# 83919238  fa123d6ebfc13851cc2ef63cdd55b5ed       набор посудыдля супа      0
#
#          locale  weekday      time
# ...

# %%
firstuser = df.loc[df['wbuser_id'] == '37bc0ce12ffabce1b1882e66d461ed0e']
firstuser
# Out:
#                                  wbuser_id                        UQ    cnt  \
# 0         37bc0ce12ffabce1b1882e66d461ed0e  тапочки женские домашние   1933
# 819       37bc0ce12ffabce1b1882e66d461ed0e  тапочки женские домашние   2191
# 202723    37bc0ce12ffabce1b1882e66d461ed0e  тапочки женские домашние   8954
# 216490    37bc0ce12ffabce1b1882e66d461ed0e  тапочки женские домашние   1651
# 226768    37bc0ce12ffabce1b1882e66d461ed0e  тапочки женские домашние     13
# ...                                    ...                       ...    ...
# 83102436  37bc0ce12ffabce1b1882e66d461ed0e    джины на высокой талии  18792
# 83110815  37bc0ce12ffabce1b1882e66d461ed0e    джины на высокой талии  10904
# 83252844  37bc0ce12ffabce1b1882e66d461ed0e    джины на высокой талии  10847
# 83333946  37bc0ce12ffabce1b1882e66d461ed0e    джины на высокой талии  10847
# 83438142  37bc0ce12ffabce1b1882e66d461ed0e    джины на высокой талии  10847
#
#          locale  weekday      time
# ...

# %%
firstuser.to_csv("first_user.csv", sep='\t', encoding='utf-8')

# %%
region = df.loc[df['locale'] != 'Ru']
region
# Out:
#                                  wbuser_id                                 UQ  \
# 23        277d8134dc3473996959f45fbc0d8c47                 Бигуди на липучках
# 69        8b926cd6f03c5f9b4fd660834932c2c5                  Самоклейка скидки
# 77        0e0b58649aee2af66e01edcc0715042a                  Крассовки жкнские
# 115       305c4f3d0a2d161ab09dc352f716851e            ботинки женские осенние
# 133       27dbab6cc712cf5f580008d5f098faea              светодиодная гирлянда
# ...                                    ...                                ...
# 83919138  8ed26798383dbd11d9f6d8e982198f4c               mark formelle пижама
# 83919150  755b8b9da1c3b98c1c432190af28770c                         Abrocrombe
# 83919155  b709b47eab31af7b2e0739da9d1dd5b3  полукомбинезон зимний для девочки
# 83919170  4664c2eb9e6cf91b3dec22a4b61500f6                               спот
# 83919231  122973d66d65550adbd7934b542d288c                    сптцы дереянные
#
# ...

# %%
# Out:
#                           wbuser_id                        UQ    cnt locale  \
# 0  37bc0ce12ffabce1b1882e66d461ed0e  тапочки женские домашние   1933     Ru
# 1  4636a6706e6736d818816d8657565aa2        чехол для бейджика   1513     Ru
# 2  708f4040baf99acfc9496563edff1b1a                     GUESS      4     Ru
# 3  70311ec9008a31f743c164e6f1198c86          штора для ванной      0     Ru
# 4  70311ec9008a31f743c164e6f1198c86                  фототфон  92272     Ru
# 5  3d5e0b035ee04de0801692081278ef1a                      7024     93     Ru
# 6  70311ec9008a31f743c164e6f1198c86     туфли мужские осенние  77232     Ru
# 7  70311ec9008a31f743c164e6f1198c86          леггинсы женские  17898     Ru
# 8  4d269edf958e9b338258d5303a92c124         чехол на айфон 11  64677     Ru
# 9  e2382a1810411d2860da0c2e75c5b695  ботинки женские мембрана    507     Ru
#
#    weekday      time
# 0        0  10:48:53
# 1        0  10:48:53
# 2        0  10:48:53
# 3        0  10:48:53
# ...

# %%
df[:100000].to_csv("first_over9000.csv", sep='\t', encoding='utf-8')
